# %% [markdown]
# # Cleaning Variables

# %%
import pandas as pd
import numpy as np

# %%
dataset = 'NC Stats Data'
variable = 'counselors'

filepath = r'C:\Users\ricke\OneDrive\Desktop\DTSC4301A\Sprint 2' + '\\' + dataset + '\\' + variable + '\\'

years = [2015, 2016, 2017, 2018, 2019, 2020, 2021]
counselor_df =pd.DataFrame()

## for every file in counselors folder
for x in years:

    ## open file    
    ## read as data frame
    sheet = pd.read_excel(filepath + 'Staff_' + str(x) + '.xlsx' , index_col = None, skiprows = [0, 1, 2], header=0, usecols=[1, 2, 3, 4, 5, 7, 8, 10, 11, 12])

    ## remove all but counselors
    sheet = sheet[sheet['Activity Assignment Classification'] == 'Guidance']

    ## add the year as a column
    sheet.insert(0, 'year', x)


    ## add to a new dataframe
    counselor_df = pd.concat([counselor_df, sheet])

counselor_df.reset_index(inplace=True)
counselor_df.drop(columns='index', inplace=True)

## checking the dataframe
counselor_df.head(10)

#counselor_df.to_csv('Counselor_Info.csv')
# Out:
#    year Activity Assignment Classification  State Funds  Fed Funds  \
# 0  2015                           Guidance        261.0        9.0
# 1  2016                           Guidance        311.0       12.0
# 2  2017                           Guidance        401.0       25.0
# 3  2018                           Guidance        409.0       30.0
# 4  2019                           Guidance        397.0       28.0
# 5  2020                           Guidance        384.0       26.0
# 6  2021                           Guidance        455.0       26.0
#
#    Local Funds  Total Funds  Gender Male  Gender Female  Race White  \
# 0         91.0        361.0         58.0          303.0       160.0
# 1         78.0        401.0         65.0          336.0       171.0
# 2          4.0        430.0         65.0          358.0       183.0
# 3          5.0        444.0         66.0          372.0       180.0
# 4         42.0        467.0         77.0          384.0       198.0
# 5         98.0        508.0        426.0           73.0       217.0
# 6         83.0        564.0         79.0          474.0       233.0
#
#    Race Black  Race Other
# 0       185.0        16.0
# 1       210.0        20.0
# 2       227.0        20.0
# 3       246.0        18.0
# 4       252.0        17.0
# 5       268.0        23.0
# 6       304.0        27.0

# %%
# print(counselor_df['Total Funds'].size)
# print(counselor_df['Total Funds'].isna().sum())
# print(counselor_df['Total Funds'].mean())
# print(counselor_df['Total Funds'].median())
# print(counselor_df['Total Funds'].std())

# %%
# dataset = 'NC Stats Data'
variable = 'schools'
filepath = r'C:\Users\ricke\OneDrive\Desktop\DTSC4301A\Sprint 2' + '\\' + dataset + '\\' + variable + '\\'


schools_df = pd.read_csv(filepath + 'Schools.csv', header=0, names=['school', 'agency_code', 'zip_code'], usecols=[2, 3, 6], dtype={'agency_code': 'object'})

# %%
variable = 'intentions'
filepath = r'C:\Users\ricke\OneDrive\Desktop\DTSC4301A\Sprint 2' + '\\' + dataset + '\\' + variable + '\\'

intentions_df = pd.DataFrame()

intention_subtotals= ['>>> Subtotal for Public SR >>>',
 '>>> Subtotal for Private SR >>>',
 '>>> Subtotal for Comm College >>>',
 '>>> Subtotal for Private JR >>>',
 '>>> Subtotal for Trade >>>',
 'MILITARY',
 'EMPLOYMENT',
 'OTHERS **']

for x in years:


    ## open file    
    ## read as data frame
    sheet = pd.read_excel(filepath + 'Intentions_' + str(x) + '.xlsx' , index_col = None, skiprows = [0, 1, 2], header=0, usecols=[1, 2, 3, 4, 5, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 21])


    ## remove subtotal rows,
    ## sheet.drop(labels=[2, 5, 8, 11, 14, 18, 19, 20, 21], axis=0, inplace=True)

    ## use subtotal rows
    sheet = sheet[sheet['Graduate Intention'].isin(intention_subtotals)]

    ## add the year as a column
    sheet.insert(0, 'year', x)

    ## add to a new dataframe
    intentions_df = pd.concat([intentions_df, sheet])

## remove '>>>' from each entry
intentions_df['Graduate Intention'] = intentions_df['Graduate Intention'].str.replace('>>>','')
## remove trailing/leading whitespaces
intentions_df['Graduate Intention'] = intentions_df['Graduate Intention'].str.strip()

## reset index
intentions_df.reset_index(drop=True, inplace=True, )

intentions_df.dropna(inplace=True)

#intentions_df.to_csv('Grad_Intentions.csv')

# %%
## getting only the percentage of graduates in each category

intentions_pivot = intentions_df[['year', 'Graduate Intention', 'Percent']]
intentions_pivot = intentions_pivot.pivot(index='year', columns='Graduate Intention', values='Percent').reset_index()
intentions_pivot
# Out:
# Graduate Intention  year  EMPLOYMENT  MILITARY  OTHERS **  \
# 0                   2015         8.3       2.9        2.7
# 1                   2016         9.3       2.7        1.9
# 2                   2017         9.7       2.6        3.1
# 3                   2018         9.3       2.3        1.2
# 4                   2019        14.0       3.0        1.1
# 5                   2020        15.0       2.2        1.0
# 6                   2021        32.9       3.0        0.9
#
# Graduate Intention  Subtotal for Comm College  Subtotal for Private JR  \
# 0                                        36.9                      0.4
# 1                                        35.1                      0.5
# 2                                        31.3                      0.2
# 3                                        35.4                      0.4
# 4                                        32.7                      0.3
# 5                                        32.3                      0.2
# 6                                        29.6                      0.2
#
# Graduate Intention  Subtotal for Private SR  Subtotal for Public SR  \
# 0                                       9.3                    38.4
# 1                                       9.5                    40.0
# 2                                       8.9                    43.4
# 3                                       9.2                    41.4
# 4                                       8.2                    39.8
# 5                                       7.8                    40.4
# 6                                       7.2                    25.6
#
# Graduate Intention  Subtotal for Trade
# 0                                  1.1
# 1                                  0.9
# 2                                  0.7
# 3                                  0.7
# 4                                  1.0
# 5                                  1.0
# 6                                  0.6

# %%
dataset = 'NC Report Card Data'
variable = 'AP Classes'
filepath = r'C:\Users\ricke\OneDrive\Desktop\DTSC4301A\Sprint 2' + '\\' + dataset + '\\' + variable + '\\'

## read excel file 
AP_df = pd.read_excel(filepath + 'NC_AP'  + '.xlsx' , index_col = None, header=0, usecols=[0, 1, 2, 3, 5])

## choose only Charlotte-Mecklenburg Schools 
AP_df = AP_df[ AP_df['agency_code'].str.startswith('600') == True]

## choose only high schools
AP_df = AP_df[ AP_df['category_code'] == 'H']

## write to CSV
#AP_df.to_csv('AP Data.csv')
# Out:
#       year agency_code category_code  pct_ap_pass  pct_ap_participation
# 306   2014      600302             H     0.830000               0.39000
# 307   2014      600312             H     0.660000               0.31000
# 308   2014      600334             H     0.530000               0.72000
# 309   2014      600361             H     0.680000               0.24000
# 311   2014      600377             H     0.440000               0.11000
# ...    ...         ...           ...          ...                   ...
# 3703  2020      600567             H     0.762712               0.20775
# 3704  2020      600576             H     0.071429               0.09406
# 3705  2020      600579             H     0.117978               0.12241
# 3707  2020      600592             H     0.194444               0.12758
# 3708  2020      600594             H     0.600000               0.25143
#
# [187 rows x 5 columns]

# %%
## highschool only codes
agency_codes = list(AP_df['agency_code'].drop_duplicates())

# %%
# data items, missing , mean, median, sd
# print(AP_df['pct_ap_pass'].size)
# print(AP_df['pct_ap_pass'].isna().sum())
# print(AP_df['pct_ap_pass'].mean())
# print(AP_df['pct_ap_pass'].median())
# print(AP_df['pct_ap_pass'].std())

# %%
# print(AP_df['pct_ap_participation'].size)
# print(AP_df['pct_ap_participation'].isna().sum())
# print(AP_df['pct_ap_participation'].mean())
# print(AP_df['pct_ap_participation'].median())
# print(AP_df['pct_ap_participation'].std())

# %%
dataset = 'NC Report Card Data'
variable = 'CTE Certifications'
filepath = r'C:\Users\ricke\OneDrive\Desktop\DTSC4301A\Sprint 2' + '\\' + dataset + '\\' + variable + '\\'

credentials_df = pd.read_excel(filepath + 'CTE_Credentials'  + '.xlsx' , index_col = None, header=0, usecols=[0, 1, 4])

credentials_df = credentials_df.loc[ credentials_df['agency_code'].isin(agency_codes), : ]

#credentials_df.to_csv('Credentials Data.csv')

# %%
creds_enroll_df = pd.read_excel(filepath + 'CTE_Enrollment' +'.xlsx', index_col = None, header=None, skiprows=[0], names=['year', 'agency_code', 'students_CTE_pct'], usecols=[0,1,4])
creds_enroll_df
# Out:
#       year agency_code  students_CTE_pct
# 0     2018      00A000              6.64
# 1     2018      00B000              1.62
# 2     2018      010303             41.36
# 3     2018      010310             55.86
# 4     2018      010324             72.23
# ...    ...         ...               ...
# 3697  2020      990LEA             59.27
# 3698  2020      995316             94.67
# 3699  2020      995324             27.66
# 3700  2020      995330             80.45
# 3701  2020      995LEA             61.64
#
# [3702 rows x 3 columns]

# %%
creds_merged_df = credentials_df.merge(creds_enroll_df, on=['year', 'agency_code'])

# %%
# print(credentials_df['num_credentials'].size)
# print(credentials_df['num_credentials'].isna().sum())
# print(credentials_df['num_credentials'].mean())
# print(credentials_df['num_credentials'].median())
# print(credentials_df['num_credentials'].std())

# %%
dataset = 'NC Report Card Data'
variable = 'College Enrollment'
filepath = r'C:\Users\ricke\OneDrive\Desktop\DTSC4301A\Sprint 2' + '\\' + dataset + '\\' + variable + '\\'

college_df = pd.read_excel(filepath + 'college enrollment'  + '.xlsx' , index_col = None, header=0, usecols=[1, 2, 3, 4, 6])

college_df = college_df.loc[ college_df['agency_code'].isin(agency_codes), : ]
college_df.rename( columns = {'graduation_year' : 'year'}, inplace=True)
college_df.drop(college_df[ college_df['Status'] == 'NOENRO' ].index, inplace=True)

#college_df.to_csv('College Enrollment Data.csv')

# %%
group_definitions = pd.read_excel(filepath + 'Subgroup_Definitions' + '.xlsx', index_col = None, header=None, names=['subgroup', 'Subgroup_Full'])
group_definitions['subgroup'] = group_definitions['subgroup'].str.strip()
## this dictionary can be used to replace all the subgroup codes with full-text

# %%
college_df = college_df.merge(group_definitions, on='subgroup')

# %%
college_pivot = pd.pivot_table(college_df, index= ['year', 'agency_code'], columns='subgroup').reset_index()

college_pivot.columns = college_pivot.columns.to_flat_index()

college_pivot.columns = [
    'year', 
    'agency_code', 
    'enroll_All',
    'enroll_AmericanIndian',
    'enroll_Asian',
    'enroll_Black',
    'enroll_Disadvantaged',
    'enroll_EnglishLearners',
    'enroll_Female',
    'enroll_Hispanic',
    'enroll_Male', 
    'enroll_Twoormore',
    'enroll_PacificIslander',
    'enroll_Disabilities',
    'enroll_White']

# %%
college_pivot
# Out:
#      year agency_code  enroll_All  enroll_AmericanIndian  enroll_Asian  \
# 0    2011      600302      0.8883                 0.9500      0.877500
# 1    2011      600334      0.8750                 0.9500      0.950000
# 2    2011      600361      0.7851                 0.6666      0.809500
# 3    2011      600364      0.7000                    NaN      0.950000
# 4    2011      600377      0.7225                 0.9500      0.888800
# ..    ...         ...         ...                    ...           ...
# 208  2019      600567         NaN                    NaN           NaN
# 209  2019      600576         NaN                    NaN           NaN
# 210  2019      600579         NaN                    NaN      0.521739
# 211  2019      600592         NaN                    NaN           NaN
# 212  2019      600594         NaN                    NaN           NaN
#
#      enroll_Black  enroll_Disadvantaged  enroll_EnglishLearners  \
# 0        0.847000                0.8070                0.750000
# 1        0.914200                0.8518                0.950000
# 2        0.698200                0.7310                0.666600
# 3        0.625000                0.7500                     NaN
# 4        0.689600                0.6601                0.586200
# ..            ...                   ...                     ...
# 208      0.709677                   NaN                     NaN
# 209      0.376068                   NaN                     NaN
# 210      0.438095                   NaN                     NaN
# 211      0.435484                   NaN                0.267857
# 212      0.608696                   NaN                     NaN
#
#      enroll_Female  enroll_Hispanic  enroll_Male  enroll_Twoormore  \
# 0         0.884200         0.791600     0.892300            0.9500
# 1         0.894700         0.600000     0.833300               NaN
# 2         0.809600         0.636300     0.758400            0.9000
# 3         0.666600         0.950000     0.750000               NaN
# 4         0.745100         0.523800     0.688400            0.5714
# ..             ...              ...          ...               ...
# 208       0.742857         0.526316     0.642857               NaN
# 209       0.400000              NaN     0.290323               NaN
# 210       0.454545              NaN     0.343195            0.5200
# 211       0.461538         0.247863     0.330000               NaN
# 212       0.714286              NaN     0.545455               NaN
#
#      enroll_PacificIslander  enroll_Disabilities  enroll_White
# 0                       NaN             0.842100        0.9094
# 1                       NaN                  NaN        0.8181
# 2                       NaN             0.407400        0.8291
# 3                       NaN             0.950000           NaN
# 4                       NaN             0.300000        0.8174
# ..                      ...                  ...           ...
# 208                     NaN                  NaN        0.7500
# 209                     NaN                  NaN           NaN
# 210                     NaN                  NaN           NaN
# 211                     NaN             0.342857           NaN
# 212                     NaN                  NaN        0.7600
#
# [213 rows x 15 columns]

# %%
# EDS_enrollment = college_df[ (college_df['subgroup'] == 'EDS') & (college_df['Status'] == 'ENROLL')]

# print(EDS_enrollment['pct_enrolled'].size)
# print(EDS_enrollment['pct_enrolled'].isna().sum())
# print(EDS_enrollment['pct_enrolled'].mean())
# print(EDS_enrollment['pct_enrolled'].median())
# print(EDS_enrollment['pct_enrolled'].std())

# %% [markdown]
# ## Merge all of it together

# %%
main_df = schools_df[ schools_df['agency_code'].isin(agency_codes)]

## big merge statement
main_df = main_df.merge(
    AP_df[['agency_code', 'pct_ap_pass', 'pct_ap_participation', 'year']],
    on='agency_code').merge(
        counselor_df[['year', 'Total Funds']], 
        on='year').merge(
            intentions_pivot, 
            on='year').merge(
                        college_pivot,
                        on = ['year','agency_code'],
                        how='left').merge(creds_merged_df, 
                    on=['year', 'agency_code'],
                    how='left')

# %%
# main_df.columns
# Out:
# Index(['school', 'agency_code', 'zip_code', 'pct_ap_pass',
#        'pct_ap_participation', 'year', 'Total Funds', 'EMPLOYMENT', 'MILITARY',
#        'OTHERS **', 'Subtotal for Comm College', 'Subtotal for Private JR',
#        'Subtotal for Private SR', 'Subtotal for Public SR',
#        'Subtotal for Trade', 'enroll_All', 'enroll_AmericanIndian',
#        'enroll_Asian', 'enroll_Black', 'enroll_Disadvantaged',
#        'enroll_EnglishLearners', 'enroll_Female', 'enroll_Hispanic',
#        'enroll_Male', 'enroll_Twoormore', 'enroll_PacificIslander',
#        'enroll_Disabilities', 'enroll_White', 'cred_earned_pct',
#        'students_CTE_pct'],
#       dtype='object')

# %%
main_df.rename(
    columns={
        'pct_ap_pass':'AP_pass_pct',
        'pct_ap_participation':'AP_part_pct',
        'EMPLOYMENT':'int_employ',
        'MILITARY': 'int_military', 
        'OTHERS **': 'int_other', 
        'Subtotal for Comm College':'int_commcoll', 
        'Subtotal for Private JR':'int_privjr', 
        'Subtotal for Private SR':'int_privsr',
        'Subtotal for Public SR':'int_pubsr',
        'Subtotal for Trade':'int_tradesch',
        'cred_earned_pct':'CTE_cred_pct',
        'students_CTE_pct':'CTE_enroll_pct',
        'Total Funds':'total_counselors'  }, inplace=True)

# %%
main_df.columns
# Out:
# Index(['school', 'year', 'agency_code', 'zip_code', '2019_med_hh_inc',
#        'AP_pass_pct', 'AP_part_pct', 'total_counselors', 'int_employ',
#        'int_military', 'int_other', 'int_commcoll', 'int_privjr', 'int_privsr',
#        'int_pubsr', 'int_tradesch', 'enroll_All', 'enroll_AmericanIndian',
#        'enroll_Asian', 'enroll_Black', 'enroll_Disadvantaged',
#        'enroll_EnglishLearners', 'enroll_Female', 'enroll_Hispanic',
#        'enroll_Male', 'enroll_Twoormore', 'enroll_PacificIslander',
#        'enroll_Disabilities', 'enroll_White', 'CTE_cred_pct',
#        'CTE_enroll_pct'],
#       dtype='object')

# %%
zip_codes = main_df['zip_code'].unique()
zip_codes

zip_2019_median_household_income = {
    28277: 109251, 
    28105: 117852, 
    28215: 50704, 
    28212: 46688, 
    28205: 50200, 
    28208: 42570, 
    28078: 82225, 
    28227: 43990, 
    28262: np.nan,
    28269: 60423, 
    28209: 99628, 
    28270: 82270, 
    28210: 87928,
    28214: 65706, 
    28031: 91151,
    28216: 64442, 
    28273: 67621}

# %%
main_df['2019_med_hh_inc'] = main_df['zip_code'].map(zip_2019_median_household_income)

year = main_df.pop('year')

main_df.insert(1, 'year', year)

median_household_income = main_df.pop('2019_med_hh_inc')

main_df.insert(4, '2019_med_hh_inc', median_household_income)

# %%
main_df
# Out:
#                               school  year agency_code  zip_code  \
# 0            Ardrey Kell High School  2015      600302     28277
# 1                 Butler High School  2015      600361     28105
# 2    Cato Middle College High School  2015      600334     28215
# 3       East Mecklenburg High School  2015      600377     28212
# 4               Garinger High School  2015      600397     28205
# ..                               ...   ...         ...       ...
# 137          Rocky River High School  2020      600457     28227
# 138    South Mecklenburg High School  2020      600535     28210
# 139       West Charlotte High School  2020      600576     28216
# 140     West Mecklenburg High School  2020      600579     28214
# 141          William Amos Hough High  2020      600312     28031
#
#      2019_med_hh_inc  AP_pass_pct  AP_part_pct  total_counselors  int_employ  \
# 0           109251.0     0.810000      0.43000             361.0         8.3
# 1           117852.0     0.670000      0.23000             361.0         8.3
# 2            50704.0     0.520000      0.52000             361.0         8.3
# 3            46688.0     0.390000      0.11000             361.0         8.3
# 4            50200.0     0.110000          NaN             361.0         8.3
# ..               ...          ...          ...               ...         ...
# 137          43990.0     0.221698      0.11449             508.0        15.0
# 138          87928.0     0.600522      0.30399             508.0        15.0
# 139          64442.0     0.071429      0.09406             508.0        15.0
# 140          65706.0     0.117978      0.12241             508.0        15.0
# 141          91151.0     0.697778      0.40636             508.0        15.0
#
#      int_military  ...  enroll_EnglishLearners  enroll_Female  \
# 0             2.9  ...                     NaN       0.465600
# 1             2.9  ...                     NaN       0.342282
# 2             2.9  ...                     NaN       0.500000
# 3             2.9  ...                     NaN       0.373684
# 4             2.9  ...                0.053125       0.146875
# ..            ...  ...                     ...            ...
# 137           2.2  ...                     NaN            NaN
# 138           2.2  ...                     NaN            NaN
# 139           2.2  ...                     NaN            NaN
# 140           2.2  ...                     NaN            NaN
# 141           2.2  ...                     NaN            NaN
#
#      enroll_Hispanic  enroll_Male  enroll_Twoormore  enroll_PacificIslander  \
# 0                NaN     0.401600               NaN                     NaN
# 1           0.076063     0.322148               NaN                     NaN
# 2           0.083333     0.402778               NaN                     NaN
# 3           0.078947     0.268421               NaN                     NaN
# 4           0.059375     0.190625               NaN                     NaN
# ..               ...          ...               ...                     ...
# 137              NaN          NaN               NaN                     NaN
# 138              NaN          NaN               NaN                     NaN
# 139              NaN          NaN               NaN                     NaN
# 140              NaN          NaN               NaN                     NaN
# 141              NaN          NaN               NaN                     NaN
#
#      enroll_Disabilities  enroll_White  CTE_cred_pct  CTE_enroll_pct
# 0                    NaN      0.545600           NaN             NaN
# 1                    NaN      0.326622           NaN             NaN
# 2                    NaN      0.305556           NaN             NaN
# 3                    NaN      0.194737           NaN             NaN
# 4                    NaN           NaN           NaN             NaN
# ..                   ...           ...           ...             ...
# 137                  NaN           NaN           NaN           67.35
# 138                  NaN           NaN           NaN           62.60
# 139                  NaN           NaN           NaN           62.23
# 140                  NaN           NaN           NaN           82.72
# 141                  NaN           NaN           NaN           60.42
#
# [142 rows x 31 columns]

# %%
#main_df.to_csv('Full_Data.csv')
